# %%
library(dplyr)

library(ggplot2)
library(fuzzyjoin)
# Out:
# Anexando pacote: 'dplyr'
#
#
# Os seguintes objetos são mascarados por 'package:stats':
#
#     filter, lag
#
#
# Os seguintes objetos são mascarados por 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
dados_df <- read.csv("dados_df.csv")

# %%
dados_df
# Out:
#      id    Nome                                      Genero Idade Raça
# 1     1    Eleonora Arilda Penedo Gomes de Padilha   Fem    34    pardo
# 2     2    Elisângela Gabrielle de Osório            Fem    26    pardo
# 3     3    José Túlio de Cabral                      Masc   35    pardo
# 4     4    Ezequiel Edivaldo de Medeiros Sonao       Masc   24    pardo
# 5     5    Fagner Josiel dos Santos                  Masc   21    pardo
# 6     6    Magali Luzimara da Silva                  Fem    49    pardo
# 7     7    Victor Plínio Shufrouze                   Masc   29    pardo
# 8     8    Laércio Rossi                             Masc   35    pardo
# 9     9    Francisco Ângelo de Toledo Seixas         Masc   40    pardo
# 10   10    Fabrício Rangel de Gonçalves dos Santos   Masc   33    pardo
# 11   11    Laila da Silva                            Fem    54    pardo
# 12   12    Nivaldo Ademar Valverde dos Santos        Masc   34    pardo
# ...

# %%
# Converter a variável Genero para factor e definir os níveis
dados_df$Genero <- factor(dados_df$Genero, levels = c("Fem", "Masc"))

# Definir as cores para os gêneros
cores_genero <- c("Fem" = "#1F78B4", "Masc" = "#33A02C")

# Criar um gráfico de dispersão fuzzy de Genero e Raça com cores diferentes para cada gênero
ggplot(dados_df, aes(x=Genero, y=Raça, fill=Genero)) +
  geom_point(position=position_jitter(width=0.2, height=0.2), alpha=0.5) +
  labs(title="Gráfico Fuzzy de Gênero e Raça",
       x="Gênero",
       y="Raça",
       fill="Gênero") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
  scale_fill_manual(values = cores_genero)
# Out:
# plot without title
