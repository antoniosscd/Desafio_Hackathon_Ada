# %% [markdown]
# ---
# #Case Ada Hack
#
# A Jornada da Corp Solutions rumo à Diversidade e Inclusão
# Contexto Histórico:
# Nos últimos anos, temos testemunhado uma mudança significativa no mundo organizacional em direção à valorização da diversidade e inclusão. À medida que a sociedade evolui, as empresas reconhecem cada vez mais os benefícios de uma força de trabalho diversificada, incluindo maior inovação, criatividade e desempenho financeiro. Além disso, movimentos sociais e pressões externas têm levado as empresas a adotarem práticas mais inclusivas e equitativas.
#
# O Desafio da Corp Solutions:
# A Corp Solutions, uma empresa líder no mercado de tecnologia para recursos humanos, recentemente recebeu um aporte milionário de uma grande corporação dos Estados Unidos. Como parte de seu compromisso em se tornar uma referência no mercado e em promover um ambiente de trabalho diverso e inclusivo, a Corp Solutions identificou a necessidade de aumentar a diversidade dentro de sua própria equipe.
#
# A Corp Solutions acredita que a diversidade não é apenas uma questão de representatividade, mas sim uma oportunidade de impulsionar a inovação, a criatividade e o sucesso dos negócios. Reconhecendo a importância de um ambiente de trabalho inclusivo, a empresa está empenhada em criar uma cultura onde todas as vozes sejam ouvidas, valorizadas e respeitadas.
#
# O Desafio do Hackathon:
# Diante desse cenário, a Corp Solutions convoca equipes de talentos criativos e inovadores para desenvolverem soluções que ajudem a empresa a alcançar seu objetivo de aumentar a diversidade e a inclusão em sua equipe. As equipes terão acesso aos dados da empresa e aos recursos necessários para desenvolverem soluções eficazes e impactantes.
#
# Objetivos do case:
# Identificar oportunidades de aumentar a diversidade na Corp Solutions. Desenvolver soluções criativas, aplicáveis e inovadoras para promover a inclusão e equidade no ambiente de trabalho. Contribuir para a construção de uma cultura organizacional diversa, inclusiva e sustentável.
#
# Contexto da Corp Solutions:
# A Corp Solutions é uma empresa de consultoria empresarial que se destaca pela venda de softwares inovadores para RH. Recentemente, a empresa recebeu um aporte de uma grande corporação dos Estados Unidos, impulsionando sua expansão e reforçando seu compromisso em investir em iniciativas de diversidade.
#
# Setor de Atuação:
#
# Atua no setor de tecnologia para recursos humanos, oferecendo uma variedade de produtos e serviços para ajudar as empresas a melhorar sua cultura organizacional, práticas de recrutamento e retenção de talentos diversos.
#
# Cultura Organizacional:
#
# Inovação, excelência, colaboração e compromisso com a diversidade e inclusão. A empresa acredita que equipes diversas são essenciais para impulsionar a inovação e o crescimento sustentável das organizações. Além disso, valoriza a transparência, a ética e o foco no cliente em todas as suas operações.
#
# Número de Colaboradores:
#
# Com o recente investimento, a empresa planeja expandir sua equipe, dobrando o número de colaboradores até o final de 2025, atingindo o número de 850 pessoas dentro da corporação.
#
# Formato do Modelo de Trabalho:
#
# A Corp Solutions adota um modelo de trabalho flexível, que inclui opções de trabalho remoto e horários flexíveis.
#
# #__________________________________________________________________________________________________
#
# 📊 Equipe de Dados:
# 💪 Desafio:
#
# Identificar padrões de diversidade e desequilíbrios nos dados e propor soluções para promover a inclusão e equidade na empresa.
#
# Entregáveis
#
# Apresentação em powerpoint em estrutura de pitch ou um relatório executivo.
#
# Documentação técnica: arquivo jupyter notebook (comentado), dashboard do powerbi ou documento com queries, códigos ou impressões de tela da evolução do case.
# #__________________________________________________________________________________________________

# %% [markdown]
# Projeto.

# %% [markdown]
# ---
# Ferramentas utilizadas:
#
# Visual Studio Code.
#
# Linguagem de programação Python e R.
#
# Jupter Notebook.

# %%
#Importando as BiBliotecas do Python

import numpy as np # Utilizaremos para os calculos algébricos
import pandas as pd # Tratemento das estruturas dos dados 
import seaborn as sns # Configurar a plotagem dos graficos.
import matplotlib.pyplot as plt # Plotar os gráficos
import skfuzzy as fuzz #gera agupamentos

# %%
#Leitura do arquivo em '.csv'

base_dados_original = pd.read_csv('base_de_dados.csv')

base_dados_original
# Out:
#          id   id.1                                     Nome Genero  Idade  \
# 0         1      1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0
# 1         2      2         ElisÃ¢ngela Gabrielle de OsÃ³rio    Fem   26.0
# 2         3      3                   JosÃ© TÃºlio de Cabral   Masc   35.0
# 3         4      4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0
# 4         5      5                 Fagner Josiel dos Santos   Masc   21.0
# ...     ...    ...                                      ...    ...    ...
# 9995   9996   9996                       Omar Camilo da Paz   Masc   21.0
# 9996   9997   9997                Edu de Muniz Jinuyul Neto   Masc   44.0
# 9997   9998   9998                  Benedito Robert Dlievic   Masc   21.0
# 9998   9999   9999                  Bento Osvaldo do PiauÃ­   Masc   39.0
# 9999  10000  10000          Augusto JosÃ© do Rio de Tavares   Masc   35.0
#
#        RaÃ§a                                          EndereÃ§o  \
# ...

# %% [markdown]
# ---
# O arquivo original veio configurado em 'UTF-8'.
# O interpretador de caracteres está traduzindo os dados de forma incorreta, dificultando a interpretação das informações.

# %% [markdown]
# ---------------------------------
# Para resolver problemas de decodificação seguir os passos abaixo:
# #--------------------------------
#
# ![image-2.png](attachment:image-2.png)  ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ---
# #Tratamento dos dados.

# %%
#Leitura do arquivo em '.csv'

base_dados = pd.read_csv('base_de_dados')

base_dados
# Out:
#          id   id.1                                     Nome Genero  Idade  \
# 0         1      1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0
# 1         2      2           Elisângela Gabrielle de Osório    Fem   26.0
# 2         3      3                     José Túlio de Cabral   Masc   35.0
# 3         4      4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0
# 4         5      5                 Fagner Josiel dos Santos   Masc   21.0
# ...     ...    ...                                      ...    ...    ...
# 9995   9996   9996                       Omar Camilo da Paz   Masc   21.0
# 9996   9997   9997                Edu de Muniz Jinuyul Neto   Masc   44.0
# 9997   9998   9998                  Benedito Robert Dlievic   Masc   21.0
# 9998   9999   9999                   Bento Osvaldo do Piauí   Masc   39.0
# 9999  10000  10000           Augusto José do Rio de Tavares   Masc   35.0
#
#         Raça                                           Endereço  \
# ...

# %%
# Transformando em um objeto DataFrame.
base_dados = pd.DataFrame(base_dados)

base_dados
# Out:
#          id   id.1                                     Nome Genero  Idade  \
# 0         1      1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0
# 1         2      2           Elisângela Gabrielle de Osório    Fem   26.0
# 2         3      3                     José Túlio de Cabral   Masc   35.0
# 3         4      4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0
# 4         5      5                 Fagner Josiel dos Santos   Masc   21.0
# ...     ...    ...                                      ...    ...    ...
# 9995   9996   9996                       Omar Camilo da Paz   Masc   21.0
# 9996   9997   9997                Edu de Muniz Jinuyul Neto   Masc   44.0
# 9997   9998   9998                  Benedito Robert Dlievic   Masc   21.0
# 9998   9999   9999                   Bento Osvaldo do Piauí   Masc   39.0
# 9999  10000  10000           Augusto José do Rio de Tavares   Masc   35.0
#
#         Raça                                           Endereço  \
# ...

# %%
# Nome das colunas
base_dados.columns
# Out:
# Index(['id', 'id.1', 'Nome', 'Genero', 'Idade', 'Raça', 'Endereço', 'Formação',
#        'Estado', 'Tempo de casa', 'Departamento', 'Senioridade'],
#       dtype='object')

# %%
#Campara os valores das colunas linha a linha. Retorna valor booleano.
compara = base_dados['id'] == base_dados['id.1']

#Cotagem de True ou False. Se algum 'False',os valores das colunas não são 100% iguais. 
#Nesta caso apenas 'True', portando são 100% iguais, decidimos então remover a coluna 'id.1'

compara.value_counts()
# Out:
# True    10000
# Name: count, dtype: int64

# %% [markdown]
# -------------------------
# Observação 02:
#
# A coluna 'id.1' é uma duplicata da coluna 'id'. Conforme demonstrado acima
#
# ---

# %%
#Remove a coluna duplicada 'id.1'

base_dados.drop('id.1',axis=1,inplace=True)

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %% [markdown]
# ---
# Analisando inconsistências nos dados.

# %%
#Lista com todas as colunas.

c1 = 'id'
c2 ='Nome'
c3 ='Genero'
c4 ='Idade'
c5 ='Raça' 
c6 ='Endereço'
c7 ='Formação'
c8 ='Estado' 
c9 ='Tempo de casa'
c10 ='Departamento'
c11 ='Senioridade'


#Verificar coluna por coluna
#verifica = base_dados[c11]

#conta quantas ocorrencias de um valor especisico em cada coluna. 
verifica = base_dados[c4].value_counts()

verifica

# Ao começar a analise, percebemos ulgumas incossistencias e decidimos 
# olhar coluna a coluna e anotar as observações a serem tratadas.
# Out:
# Idade
# 22.0    546
# 21.0    440
# 20.0    428
# 30.0    423
# 25.0    408
#        ...
# 64.0      1
# 6.0       1
# 61.0      1
# 68.0      1
# 74.0      1
# Name: count, Length: 61, dtype: int64

# %%
valo_null = base_dados.isnull().sum()
valo_null.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of id                 0
# Nome               0
# Genero             0
# Idade             56
# Raça               0
# Endereço           0
# Formação          44
# Estado             0
# Tempo de casa    200
# Departamento       0
# Senioridade        0
# dtype: int64>

# %% [markdown]
# ---
# Inconsistências a serem tratadas.
#
# Na coluna 'Nome', percebemos nomes repetidos.
#
# Na coluna 'Gênero', observamos ausência de outros "gêneros". Sugiro mudar a coluna para 'Identidade de Gênero' e incluir todas as opções possíveis. Ao levantar os requisitos, é importante conversar com especialistas no assunto. Incluir na base uma coluna para orientação sexual para manter a base contemporânea e atualizada em relação à realidade.
#
# Na coluna 'Idade', existem pessoas com menos de 14 anos.
#
# Na coluna 'Tempo de casa', observamos a existência de valores negativos. A base de dados também não nos permite determinar se a pessoa continua na empresa ou não. Sugiro incluir duas colunas: 'Inicio de Contrato' e 'Término de Contrato'. Com essas informações, podemos estipular metas mais precisas em relação à inclusão. Porém, com os dados que temos nas mãos por enquanto, como são dados históricos, deduzimos que a quantidade atual de cada grupo seja proporcional à quantidade de registros existentes.
#
# Na coluna 'Senioridade', observamos 'Gerente' escrito com letra maiúscula e 'gerente' com letra minúscula.
#
# As colunas 'Idade', 'Formação' e 'Tempo de casa' apresentam valores nulos.

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %%
#Seleciona nomes repetidos na base.
nomes_repetidos = base_dados[base_dados.duplicated(subset=['Nome'], keep=False)]

# nomes_repetidos = base_dados[(base_dados['Nome'].value_counts()) == 2]

# repete = nomes_repetidos[(nomes_repetidos[c5] == 'indígena') & (nomes_repetidos[c3] == 'Fem')]
# print(repete[c3].value_counts())
print(len(nomes_repetidos))
# Out:
# 78

# %% [markdown]
# ---
# Nomes repetidos representam 0,78% da base de dados. Serão excluídos da análise.

# %%
#Teste exclusão
nomes_repetidos = nomes_repetidos[~nomes_repetidos['Nome'].isin(nomes_repetidos['Nome'][nomes_repetidos['Nome'].duplicated()])]

print(len(nomes_repetidos))
# Out:
# 0

# %%
#Excluindo nomes repetidos da abse_dados
base_dados = base_dados[~base_dados['Nome'].isin(base_dados['Nome'][base_dados['Nome'].duplicated()])]

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %% [markdown]
# ---
# Verificar pessoas menores de 14 anos. A partir dessa idade, no Brasil, as pessoas já podem ter relações de trabalho, desde que observadas as condições impostas por Lei.
#
# Referencias:
#
# https://portal.trt3.jus.br/internet/conheca-o-trt/comunicacao/noticias-juridicas/trabalho-infantil-no-brasil-e-no-mundo-a-maior-vulnerabilidade-de-criancas-e-adolescentes-no-cenario-pos-pandemia-covid-19
#
# https://www.planalto.gov.br/ccivil_03/decreto/2002/d4134.htm#:~:text=DECRETO%20N%C2%BA%204.134%2C%20DE%2015,M%C3%ADnima%20de%20Admiss%C3%A3o%20ao%20Emprego.&text=O%20PRESIDENTE%20DA%20REP%C3%9ABLICA%20%2C%20no,que%20lhe%20confere%20o%20art.

# %%
# Seleciona as pessoas menores de 14 anos.
menores = base_dados[base_dados['Idade']<14]

len(menores)
# Out:
# 23

# %% [markdown]
# ---
# Pessoas menores de 14 anos representam 0,23% dos dados da base atual. Pelo irrelevância, também será excluída da 'base_dados'.
#
# Mais uma vez sugerimos à inserção de restrições no banco de dados, na coluna Idade, não permitir valores menores que 14 anos. Incluindo alerta citando os perigos para empresa estabelecer relações de trabalho caracterizados como 'Trabalho Infantil'

# %%
#Teste exclusão

menores = menores[~menores['Idade'].isin(menores['Idade'][menores['Idade']<14])]


len(menores)
# Out:
# 0

# %%
menor14 = base_dados['Idade'] <14

menor14.value_counts()
# Out:
# Idade
# False    9899
# True       23
# Name: count, dtype: int64

# %%
#Excluindo menores da base_dados.

base_dados = base_dados[~base_dados['Idade'].isin(base_dados['Idade'][base_dados['Idade']<14])]

base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %%
valor_negativo = base_dados[base_dados['Tempo de casa']<0]

valor_negativo['Tempo de casa'].value_counts().sum()
# Out:
# 98

# %% [markdown]
# ---
# Encontramos 98 ocorrências de valores negativos, sendo 70 masculino e 28 feminino.
#
# Representam respectivamente 0,99%; 0,70% e 0,28% da base_base.
#
# Neste caso decidimos transformar esses valores negativos em positivos e mantê-los na análise.

# %%
#Teste trasnformar valores negativos em positivo

valor_negativo.loc[:, 'Tempo de casa'] = valor_negativo['Tempo de casa'].abs()


valor_negativo
# Out:
#         id                                   Nome Genero  Idade    Raça  \
# 62      63      Arthur Alexandre de Souza Marques   Masc   25.0   pardo
# 105    106  Adriano Uribe Irnizson Imekre Clozklo   Masc   39.0   preto
# 118    119      Verônica Betayomo da Silva Umriov    Fem   35.0   pardo
# 428    429                       Edivaldo Gloveov   Masc   28.0   preto
# 574    575              Silvair Walter de Gimenes   Masc   28.0  branco
# ...    ...                                    ...    ...    ...     ...
# 9655  9656      Roger Franco da Encarnação Júnior   Masc   32.0  branco
# 9727  9728                     Marcos Robson Ezen   Masc   19.0  branco
# 9826  9827                    Verônica de Azevedo    Fem   19.0   pardo
# 9838  9839                      Leni Fytrynalsirn    Fem   34.0   preto
# 9876  9877                         Júlio da Silva   Masc    NaN   pardo
#
#                                                Endereço         Formação  \
# ...

# %%
#trasnforma valores negativos em positivo
base_dados.iloc[:, 8] = base_dados.iloc[:, 8].abs()

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %% [markdown]
# ---
# Ajustado os nomes na coluna 'Senioridade' para que todos os valores apareçam com a primeira letra Maiúscula.

# %%
base_dados.loc[:, 'Senioridade'] = base_dados['Senioridade'].str.title()

base_dados['Senioridade'].value_counts()


#Oserve que 'gerente' não aparece mais.
# Out:
# Senioridade
# Analista Júnior    2966
# Analista Pleno     2478
# Analista Sênior    1977
# Gerente            1497
# Estagiário          893
# Diretor              88
# Name: count, dtype: int64

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %% [markdown]
# ----
# Tratando os valores Nulos

# %%
linhas_null = base_dados[base_dados.isnull().any(axis=1)]

linhas_null
# Out:
#         id                                      Nome Genero  Idade    Raça  \
# 30      31                           Valdirene Nunes    Fem   32.0   pardo
# 33      34                    Juliano d'Ávila Júnior   Masc   43.0  branco
# 90      91  Ariana Quésia Buarque de Sales Noshiguke    Fem   31.0   pardo
# 160    161                    João Rosatto do Amaral   Masc   19.0   pardo
# 173    174                  Paulo Alexandre da Silva   Masc   32.0   pardo
# ...    ...                                       ...    ...    ...     ...
# 9866  9867           Manuel Azpunason da Silva Gomes   Masc   42.0   preto
# 9876  9877                            Júlio da Silva   Masc    NaN   pardo
# 9933  9934                  Itamar Sílvio Rossi Neto   Masc    NaN   pardo
# 9937  9938               Tomáz de Madureira Coutinho   Masc   27.0   pardo
# 9952  9953           Celso Luigi de Silveira Fragoso   Masc   57.0  branco
#
# ...

# %% [markdown]
# ---
# A base encontrasse com 280 registos com valores nulos em pelo menos uma coluna. Esse valor representa 2,83% da base_dados atual. Pela irrelevância será excluído da análise.

# %%
#Teste excluir linhas com valores nulos.

linhas_null = linhas_null.dropna()

linhas_null
# Out:
# Empty DataFrame
# Columns: [id, Nome, Genero, Idade, Raça, Endereço, Formação, Estado, Tempo de casa, Departamento, Senioridade]
# Index: []

# %%
#Excluinso linhas com valores nulos em base_dados

base_dados = base_dados.dropna()

base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %% [markdown]
# ---
#
# Finalizada o tratamento dos dados.
#
# Foram excluídos 381 registos considerados inconsistentes, que representam 3,81% da base de dados original.

# %% [markdown]
# ---
# Analise quantitativa dos dados

# %%
#Informações gerais
print(base_dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9619 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             9619 non-null   int64
#  1   Nome           9619 non-null   object
#  2   Genero         9619 non-null   object
#  3   Idade          9619 non-null   float64
#  4   Raça           9619 non-null   object
#  5   Endereço       9619 non-null   object
#  6   Formação       9619 non-null   object
#  7   Estado         9619 non-null   object
#  8   Tempo de casa  9619 non-null   float64
#  9   Departamento   9619 non-null   object
#  10  Senioridade    9619 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 901.8+ KB
# None

# %%
#Analise Descritiva das colunas numericas 'Idade' e 'Tempo de casa'.
print(base_dados['Idade'].describe())
print(base_dados['Tempo de casa'].describe())
# Out:
# count    9619.000000
# mean       30.903940
# std         8.665758
# min        15.000000
# 25%        24.000000
# 50%        30.000000
# 75%        37.000000
# max        74.000000
# Name: Idade, dtype: float64
# count    9619.000000
# mean        5.520948
# std         2.904069
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        17.000000
# Name: Tempo de casa, dtype: float64

# %%
#Agrupamento de pessoas femininas entre 14 1 17 anos

fem_grupo = base_dados[(base_dados['Genero']=='Fem') & ((base_dados['Idade']>=14) & (base_dados['Idade']<=17))]

fem_grupo
# Out:
#         id               Nome Genero  Idade      Raça  \
# 6599  6600  Samara de Pereira    Fem   15.0  indígena
#
#                               Endereço         Formação Estado  Tempo de casa  \
# 6599  PSC 1630, Box 4815\nAPO AA 90695  Ensino Superior  Ceará            5.0
#
#           Departamento Senioridade
# 6599  Recursos Humanos  Estagiário

# %% [markdown]
# ---
# Observando as Idade e Tempo de casa, Samara de Pereira, entrou na empresa aos 10 anos. Mais uma inconsistência a ser tratada. Vamos Analisar.

# %% [markdown]
# ---

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9995   9996                       Omar Camilo da Paz   Masc   21.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %%
#A informação assima indica uma falha que sera analisada.
grupo_inc = []

for index, linha in base_dados.iterrows():
    if (linha['Idade'] - linha['Tempo de casa']) < 14:
        grupo_inc.append(linha)

# Exibir as primeiras linhas do grupo_inc
# print(pd.DataFrame(grupo_inc).head())

grupo_inc = pd.DataFrame(grupo_inc)

grupo_inc
# Out:
#         id                                       Nome Genero  Idade    Raça  \
# 12      13                 Mariano Rosa da Graça Neto   Masc   18.0   preto
# 14      15          Marlon Rafael do Nascimento Uason   Masc   19.0  branco
# 18      19              Adônis Otto de Aguiar da Lira   Masc   18.0  branco
# 32      33                              Berenice Tono    Fem   18.0  branco
# 55      56                           Arnaldo de Lemos   Masc   21.0  branco
# ...    ...                                        ...    ...    ...     ...
# 9894  9895  Nicolau de Torquato Mendes Marinho Júnior   Masc   19.0  branco
# 9920  9921                Dário Abílio de Paula Fipio   Masc   22.0   preto
# 9934  9935  Clarice Flávia de Almeida Estrada Gradrie    Fem   18.0  branco
# 9989  9990           Jackson Amaer de Pacheco Yakishi   Masc   21.0   pardo
# 9995  9996                         Omar Camilo da Paz   Masc   21.0   pardo
#
# ...

# %% [markdown]
# ---
# Verificando o tempo de casa e idade dos funcionários encontramos 768 registros que indicam que esses funcionários entraram na empresa com idade inferior a 14 anos. Deve ser erro de inserção. Esses registros representam 7,8% dos dados atuais de base_dados.
#
# Serão excluídos da análise.
#
# ---

# %%
# Verificando a quantidade de homens e mulheres com essa inconsistencia. 


grupo_inc['Genero'].value_counts()
# Out:
# Genero
# Masc    581
# Fem     187
# Name: count, dtype: int64

# %%
# Cria uma variavel com os valores dos indices do grupo_inc e com base nesses valores, os indices 
#em base_dados são excluidos.
grupo_inc_exl = grupo_inc.index
base_dados = base_dados.drop(grupo_inc_exl)

# %%
base_dados
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9994   9995                     Gilson Izhi de Bueno   Masc   38.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %%
print(base_dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8851 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             8851 non-null   int64
#  1   Nome           8851 non-null   object
#  2   Genero         8851 non-null   object
#  3   Idade          8851 non-null   float64
#  4   Raça           8851 non-null   object
#  5   Endereço       8851 non-null   object
#  6   Formação       8851 non-null   object
#  7   Estado         8851 non-null   object
#  8   Tempo de casa  8851 non-null   float64
#  9   Departamento   8851 non-null   object
#  10  Senioridade    8851 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 829.8+ KB
# None

# %% [markdown]
# ---
# Após esse comando, as exclusões somam 1149 registos, que representa 11,49% da base original.
#
# ---

# %%
#Outra forma de verificar o tratamento feito anteriormente.
grupo_inc2 = []

for index, linha in base_dados.iterrows():
    if (linha['Idade'] - linha['Tempo de casa']) < 14:
        grupo_inc2.append(linha)

# Exibir as primeiras linhas do grupo_inc2
# print(pd.DataFrame(grupo_inc2).head())

grupo_inc2 = pd.DataFrame(grupo_inc2)

# %%
base_dados.insert(len(base_dados.columns), 'Vlr%', (1/len(base_dados)))

# %%
valor_relativo = base_dados.groupby('Raça')['Vlr%'].sum()

# %%
print(valor_relativo*850)
print(valor_relativo*0.5148)
# Out:
# Raça
# amarelo       4.033443
# branco      368.867925
# indígena      4.225511
# pardo       396.429782
# preto        76.443340
# Name: Vlr%, dtype: float64
# Raça
# amarelo     0.002443
# branco      0.223404
# indígena    0.002559
# pardo       0.240097
# preto       0.046298
# Name: Vlr%, dtype: float64

# %%
valor_relativo
# Out:
# Raça
# amarelo     0.004745
# branco      0.433962
# indígena    0.004971
# pardo       0.466388
# preto       0.089933
# Name: Vlr%, dtype: float64

# %%
len(base_dados['Nome'])
# Out:
# 8851

# %% [markdown]
# ---
# Retomando a análise Quantitativa
#
# Lembrando que são registros históricos e a base não nos dá a quantidade exata de funcionários, sabemos que são 425 pelo enunciado do Problema.
#
# ---

# %% [markdown]
# Contagem de Genero.
#
# ---

# %%
base_dados['Genero'].value_counts()
# Out:
# Genero
# Masc    6613
# Fem     2238
# Name: count, dtype: int64

# %%
contagem_genero = base_dados['Genero'].value_counts() / len(base_dados['Genero'])


plt.figure(figsize=(8, 6))
contagem_genero.plot(kind='bar', color=['blue', 'pink'])
plt.title('Contagem de Gênero')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.xticks(rotation=0)
for i, value in enumerate(contagem_genero):
    plt.text(i, value, f"{value*8851:.0f} ({value:.2f}%)", ha='center', va='bottom')

plt.show()

# %% [markdown]
# ---
# A empresa tem, em seu histórico, a tendência de contratar mais o gênero masculino, representando 75%, enquanto o gênero feminino representa apenas 25%. Por outro lado, segundo o último censo, a população brasileira é representada por 51,48% de mulheres e 48,51% de homens. Há uma evidente discrepância ao compararmos esses números.

# %% [markdown]
# ---
#
# A intenção é equalizar os gêneros. Vamos criar uma tabela contendo os dados atuais, os dados do censo de 2022 e as metas mensais até 2026 de cada grupo, e gerar um gráfico com esses dados.
#
# ---

# %%
#Gerando as metas para Genero.
total_funcionarios = 850 #meta para o quardro ate 2026
quadro_atual = 425 #Quadro atual 
tempo_mes = 18 #Quantos meses faltam para 2026
genero_meta = {}  #Dicionario Vazio para armazenar as tabelas.

# Tabela com dados do censo de 2022. A chave 'Total%' mapeia o valor relativo de cada grupo dentro da 
# população.
ibge = {
    'Genero':['Masc','Fem'],
    'Total%':[0.4851,0.5148]
         } 
ibge = pd.DataFrame(ibge)

#Descreve as metas mensais e o total até 2026 de cada grupo.

genero_meta= {
    'Genero':['Masc','Fem'],
    #Calculamos a proporção atual de cada grupo com base nos valores relativos nos dados históricos, 
    # seguindo a fórmula total_do_grupo / total_de_registros. Essa proporção é obtida dividindo o total 
    # de cada grupo pelo total de registros. Com esse cálculo, podemos deduzir a quantidade atual de 
    # cada grupo, já que os dados não nos fornecem essa informação.  
    'Atual': [round(quadro_atual * ((base_dados['Genero']=='Masc').sum())/len(base_dados['Genero'])), 
              round(quadro_atual * ((base_dados['Genero']=='Fem').sum())/len(base_dados['Genero']))],
    #Descreve os valores relativos de cada grupo segundo ibge.
    'IBGE%': [48.51,51.48],
    #Calcula o total de 850 multiplicado pelo valor relativo do grupo no censo de 2022, obtendo a meta do grupo para 2026.
    'Meta 2026': [round(total_funcionarios * ibge['Total%'][0]),
                  round(total_funcionarios * ibge['Total%'][1])],
    #Calcula o total de 850 multiplicado pelo valor relativo do grupo no censo de 2022, obtendo a meta do grupo para cada mês.
    'Meta mes' :[round(total_funcionarios * ibge['Total%'][0] / tempo_mes),
                 round(total_funcionarios * ibge['Total%'][1] / tempo_mes)]
}
genero_meta = pd.DataFrame(genero_meta)

genero_meta
# Out:
#   Genero  Atual  IBGE%  Meta 2026  Meta mes
# 0   Masc    318  48.51        412        23
# 1    Fem    107  51.48        438        24

# %%
ibge = pd.DataFrame(ibge)

ibge
# Out:
#   Genero  Total%
# 0   Masc  0.4851
# 1    Fem  0.5148

# %%
plt.figure(figsize=(10, 6))
barWidth = 0.20


r1 = range(len(genero_meta))


plt.bar(r1, genero_meta['Atual'], color='c', width=barWidth, edgecolor='grey', label='Atual')
plt.bar([r + barWidth for r in r1], genero_meta['Meta 2026'], color='y', width=barWidth, edgecolor='grey', label='Meta 2026')
plt.bar([r + 2*barWidth for r in r1], genero_meta['Meta mes'], color='pink', width=barWidth, edgecolor='grey', label='Meta mes')


for i, value in enumerate(genero_meta['Atual']):
    plt.text(i, value + 5, str(value), color='black', ha='center')
for i, value in enumerate(genero_meta['Meta 2026']):
    plt.text(i + barWidth, value + 5, str(value), color='black', ha='center')
for i, value in enumerate(genero_meta['Meta mes']):
    plt.text(i + 2*barWidth, value + 5, str(value), color='black', ha='center')


plt.xlabel('Gênero', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(genero_meta))], genero_meta['Genero'])
plt.ylabel('Valores')
plt.title('Comparação entre Atual e Meta 2026 por Gênero')
plt.legend()

plt.show()

# %%
total_funcionarios = 850
tempo_mes = 18

# %%
raca_ibge = pd.read_csv('raca_ibge.csv', sep=';', encoding='ANSI')
raca_ibge = pd.DataFrame(raca_ibge)

raca_ibge
# Out:
#        Raça  % Populacao
# 0     pardo        45.35
# 1    branco        43.46
# 2     preto        10.17
# 3  indígena         0.60
# 4   amarelo         0.42

# %%
raca_emp = base_dados['Raça'].value_counts()
raca_emp = pd.DataFrame(raca_emp)

raca_emp
# Out:
#           count
# Raça
# pardo      4128
# branco     3841
# preto       796
# indígena     44
# amarelo      42

# %%
print(raca_emp.columns)
# Out:
# Index(['count'], dtype='object')

# %%
total_emp = raca_emp['count'].sum()
total_ibge = raca_ibge['% Populacao'].sum()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Definir paleta de cores
colors_emp = plt.cm.tab20(np.linspace(0, 1, len(raca_emp)))
colors_ibge = plt.cm.tab20b(np.linspace(0, 1, len(raca_ibge)))

# Gráfico distribuição das raças na empresa
bars_emp = ax1.bar(raca_emp.index, raca_emp['count'], color=colors_emp)
ax1.set_xlabel('Raça')
ax1.set_ylabel('Quantidade')
ax1.set_title('Distribuição das Raças na Empresa')
for bar, color in zip(bars_emp, colors_emp):
    yval = bar.get_height()
    percentage = round((yval / total_emp) * 100, 2)
    ax1.text(bar.get_x() + bar.get_width()/2, yval + 0.05, f'{percentage}%', ha='center', va='bottom', color='black')

# Gráfico distribuição das raças censo 2022.
bars_ibge = ax2.bar(raca_ibge['Raça'], raca_ibge['% Populacao'], color=colors_ibge)
ax2.set_xlabel('Raça')
ax2.set_ylabel('% População')
ax2.set_title('Distribuição das Raças censo 2022')
for bar, color in zip(bars_ibge, colors_ibge):
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval + 0.5, f'{yval}%', ha='center', va='bottom', color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# Em relação às raças, observamos uma distribuição mais homogênea, porém é necessário ajustar a representatividade das categorias preto, amarelo e indígena.
#
# ---

# %% [markdown]
# ---
#
# Abaixo, criamos uma tabela com os dados das metas para cada raça. Os cálculos foram feitos com o mesmo princípio anteriormente utilizado para o gênero. Em seguida, geramos um gráfico com as metas.
#
# ---

# %%
total_funcionarios = 850
tempo_mes = 18
quadro_atual = 425

atual = base_dados['Raça'].value_counts(normalize=True) * quadro_atual
atual = atual.reindex(['pardo', 'branco', 'preto', 'indígena', 'amarelo']).fillna(0).astype(int)

# Cálculo dos valores de 'Meta 2026' e 'Meta mes'
meta_2026 = total_funcionarios * raca_ibge['% Populacao'] / 100
meta_mes = meta_2026 / tempo_mes

# Criação do DataFrame
raca_meta = pd.DataFrame({
    'Raca': ['pardo', 'branco', 'preto', 'indígena', 'amarelo'],
    'Atual': atual.values,
    'Meta 2026': meta_2026.round().astype(int),
    'Meta mes': meta_mes.round().astype(int)
})

raca_meta
# Out:
#        Raca  Atual  Meta 2026  Meta mes
# 0     pardo    198        385        21
# 1    branco    184        369        21
# 2     preto     38         86         5
# 3  indígena      2          5         0
# 4   amarelo      2          4         0

# %%
plt.figure(figsize=(10, 4))
barWidth = 0.20

r1 = range(len(raca_meta))

for i, col in enumerate(['Atual', 'Meta 2026', 'Meta mes']):
    plt.bar([r + i*barWidth for r in r1], raca_meta[col], color=['c', 'y', 'pink'][i],
            width=barWidth, edgecolor='grey', label=col)
    for j, value in enumerate(raca_meta[col]):
        plt.text(j + i*barWidth, value + 5, str(value), color='black', ha='center')

plt.xlabel('Raça', fontweight='bold')
plt.xticks([r + barWidth for r in r1], raca_meta['Raca'])
plt.ylabel('Valores')
plt.title('Quadro Atual VS Meta 2026')
plt.legend()

plt.show()

# %% [markdown]
# ---
#
# Análisando a variavel Senioridade.
# ---

# %%
contagem_agrupada = pd.crosstab([base_dados['Genero']], base_dados['Senioridade'])
quadro_gs = round(contagem_agrupada/len(base_dados)*quadro_atual)

# Plotar o gráfico de barras agrupadas com distância entre as barras aumentada
ax = quadro_gs.plot(kind='bar', figsize=(25, 12), width=0.6)  # Ajuste a largura das barras conforme necessário
plt.title('Distribuição de Gênero e Senioridade', fontsize=14)
plt.xlabel('Gênero', fontsize=14)
plt.ylabel('Quantidade', fontsize=14)
plt.legend(title='Senioridade', fontsize=14)

# Adicionar as quantidades nas barras
for i in ax.patches:
    ax.text(i.get_x() + i.get_width() / 2, i.get_height() + 0.05, 
            str(i.get_height()), ha='center', va='bottom', fontsize=14)

plt.show()

# %%
contagem_masc = base_dados[base_dados['Genero']=='Masc']
contagem_fem = base_dados[base_dados['Genero']=='Fem']

print(contagem_fem['Senioridade'].value_counts())
print(contagem_masc['Senioridade'].value_counts())
# Out:
# Senioridade
# Analista Júnior    710
# Analista Pleno     570
# Analista Sênior    449
# Gerente            315
# Estagiário         183
# Diretor             11
# Name: count, dtype: int64
# Senioridade
# Analista Júnior    1956
# Analista Pleno     1647
# Analista Sênior    1327
# Gerente            1012
# Estagiário          602
# Diretor              69
# Name: count, dtype: int64

# %%
como_esta_fem = round(contagem_fem['Senioridade'].value_counts() / len(base_dados) * quadro_atual)

deveria_ser_fem = round(base_dados['Senioridade'].value_counts(normalize=True) * quadro_atual * 0.5148)

df_como_esta_fem = pd.DataFrame({
    'Senioridade': como_esta_fem.index,
    'Quantidade Como Está': como_esta_fem.values
})

df_deveria_ser_fem = pd.DataFrame({
    'Senioridade': deveria_ser_fem.index,
    'Quantidade Deveria Ser': deveria_ser_fem.values
})

df_merged = df_como_esta_fem.merge(df_deveria_ser_fem, on='Senioridade', how='outer')

plt.figure(figsize=(12, 6))
bar_width = 0.35
r1 = range(len(df_merged))
r2 = [x + bar_width for x in r1]
plt.bar(r1, df_merged['Quantidade Como Está'], color='skyblue', width=bar_width, label='Como Está')
plt.bar(r2, df_merged['Quantidade Deveria Ser'], color='orange', width=bar_width, label='Deveria Ser')
plt.xlabel('Senioridade')
plt.ylabel('Quantidade')
plt.title('Comparação entre Como Está e Deveria Ser (fem)')
plt.xticks([r + bar_width/2 for r in range(len(df_merged))], df_merged['Senioridade'])
plt.legend()

for i in range(len(df_merged)):
    plt.text(i, df_merged['Quantidade Como Está'][i] + 0.5, 
             str(df_merged['Quantidade Como Está'][i]), ha='center', va='bottom')
    plt.text(i + bar_width, df_merged['Quantidade Deveria Ser'][i] + 0.5, 
             str(df_merged['Quantidade Deveria Ser'][i]), ha='center', va='bottom')
plt.show()

# %%
como_esta_masc = round(contagem_masc['Senioridade'].value_counts()/len(base_dados)*quadro_atual)

deveria_ser_masc = round(base_dados['Senioridade'].value_counts(normalize=True)*quadro_atual*0.4851)

deveria_ser_masc

fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.35


r1 = np.arange(len(como_esta_masc))
r2 = [x + bar_width for x in r1]


plt.bar(r1, como_esta_masc, color='skyblue', width=bar_width, edgecolor='grey', 
        label='Quantidade Como Está')
plt.bar(r2, deveria_ser_masc, color='orange', width=bar_width, edgecolor='grey', 
        label='Quantidade Deveria Ser')


plt.title('Distribuição de Senioridade entre Homens')
plt.xlabel('Senioridade')
plt.ylabel('Quantidade')
plt.xticks([r + bar_width / 2 for r in range(len(como_esta_masc))], 
           como_esta_masc.index, rotation=45, ha='right')


plt.legend()


for i in range(len(como_esta_masc)):
    plt.text(i, como_esta_masc.iloc[i] + 0.5, 
             str(como_esta_masc.iloc[i]), ha='center', va='bottom')
    plt.text(i + bar_width, deveria_ser_masc.iloc[i] + 0.5, 
             str(deveria_ser_masc.iloc[i]), ha='center', va='bottom')
plt.show()

# %%
dados_df = base_dados.copy()

dados_df
# Out:
#          id                                     Nome Genero  Idade    Raça  \
# 0         1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0   pardo
# 1         2           Elisângela Gabrielle de Osório    Fem   26.0   pardo
# 2         3                     José Túlio de Cabral   Masc   35.0   pardo
# 3         4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0   pardo
# 4         5                 Fagner Josiel dos Santos   Masc   21.0   pardo
# ...     ...                                      ...    ...    ...     ...
# 9994   9995                     Gilson Izhi de Bueno   Masc   38.0   pardo
# 9996   9997                Edu de Muniz Jinuyul Neto   Masc   44.0   pardo
# 9997   9998                  Benedito Robert Dlievic   Masc   21.0  branco
# 9998   9999                   Bento Osvaldo do Piauí   Masc   39.0   pardo
# 9999  10000           Augusto José do Rio de Tavares   Masc   35.0  branco
#
# ...

# %%
dados_df.to_csv("dados_df.csv",index=False)
